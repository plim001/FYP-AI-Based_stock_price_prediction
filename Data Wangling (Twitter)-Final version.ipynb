# %% [markdown]
# # Li's Twitter

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "(@$LI) lang:en until:2022-08-27 since:2020-07-30"                 # Query for LI_auto tweets with date range in twitter
tweets = []
limits = 100000


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if len(tweets) == limits:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])    # creating columns
        
df = pd.DataFrame(tweets, columns=['Date','User','Tweet'])
df.to_csv('LI_tweets1.csv')                                                # to save to csv
df                                                                         # show what does df contains
# Out:
#                            Date             User  \
# 0     2022-08-26 23:17:25+00:00        mdsoll315
# 1     2022-08-26 22:36:03+00:00        mdsoll315
# 2     2022-08-26 21:57:42+00:00  Charlot68911596
# 3     2022-08-26 21:34:41+00:00        mdsoll315
# 4     2022-08-26 21:09:46+00:00   Helena59191506
# ...                         ...              ...
# 46787 2020-07-30 05:46:43+00:00        PFQdokkan
# 46788 2020-07-30 05:08:42+00:00  stonksfrmytesla
# 46789 2020-07-30 04:34:31+00:00  Plantagenet1455
# 46790 2020-07-30 04:19:53+00:00       Junheng_Li
# 46791 2020-07-30 01:22:57+00:00     BellhouseJay
#
#                                                    Tweet
# 0      $PCAR is the ONLY EV up YTD.. $Li was, but was...
# 1      I’m expecting a squeeze in all of China… espec...
# 2      $li  is set and ready for a run up!.!.~\nhttps...
# 3      “What is your moves come Monday, Steve?” \n\n“...
# 4      $LI   $49,000 a day keeps the 9 to 5 away; For...
# ...

# %% [markdown]
# # XPeng's Twitter

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "(@$XPEV) lang:en until:2022-08-27 since:2020-07-30"                 # Query for XPENG tweets with date range in twitter
tweets = []
limits = 100000                                                           # Number of tweets


for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if len(tweets) == limits:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])    # creating columns
        
df1 = pd.DataFrame(tweets, columns=['Date','User','Tweet'])
df1.to_csv('XPENG_tweets1.csv')                                                 # to save to csv
df1                                                                         # show what does df contains
# Out:
#                            Date             User  \
# 0     2022-08-26 23:17:25+00:00        mdsoll315
# 1     2022-08-26 23:05:03+00:00       AlertTrade
# 2     2022-08-26 22:36:03+00:00        mdsoll315
# 3     2022-08-26 22:30:03+00:00  TradeWithAlerts
# 4     2022-08-26 22:17:03+00:00    Jonny09775596
# ...                         ...              ...
# 68216 2020-08-07 19:52:10+00:00          sokane1
# 68217 2020-08-07 19:45:55+00:00          sokane1
# 68218 2020-08-07 19:35:22+00:00          sokane1
# 68219 2020-08-07 18:53:49+00:00     HedgeyeChina
# 68220 2020-08-07 18:50:02+00:00        JCOviedo6
#
#                                                    Tweet
# 0      $PCAR is the ONLY EV up YTD.. $Li was, but was...
# 1      💳  Order your FTX Crypto Card \nNo Fees!  Yes,...
# 2      I’m expecting a squeeze in all of China… espec...
# 3      Nice print for $XPEV Size: 247402 Price: 18.92...
# 4      $xpev   $49,000 a day keeps the 9 to 5 away; F...
# ...

# %% [markdown]
# # Nio's Twitter

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "(@$NIO) lang:en until:2022-08-27 since:2020-07-30"                             # Query for NIO tweets with date range in twitter
tweets = []
limits = 1000000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if len(tweets) == limits:                                                           # Set tweets limits for scraping
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])                 # creating columns
        
df2 = pd.DataFrame(tweets, columns=['Date','User','Tweet'])
df2.to_csv('NIO_tweets1.csv')                                                           # to save to csv
df2                                                                                     # show what does df contains
# Out:
#                             Date             User  \
# 0      2022-08-26 23:52:19+00:00         MrRabit8
# 1      2022-08-26 23:41:13+00:00    GBear03828377
# 2      2022-08-26 23:34:28+00:00         nxvember
# 3      2022-08-26 23:30:13+00:00         mephiljb
# 4      2022-08-26 23:28:47+00:00  RossCra41038894
# ...                          ...              ...
# 458662 2020-07-30 00:26:50+00:00     Jeff24458526
# 458663 2020-07-30 00:25:38+00:00      davidmoadel
# 458664 2020-07-30 00:22:16+00:00      TalkWithEli
# 458665 2020-07-30 00:14:50+00:00     bigmike48732
# 458666 2020-07-30 00:03:56+00:00         stoxline
#
#                                                     Tweet
# 0       $nio Top analyst price target for next week. \...
# 1       For next week I bought puts on $F $NIO $PLTR a...
# 2                        @YourBoyMilt $AMZN $NIO $SNOW 👀🥲
# 3       So personally I’ll get a $TSLA or $NIO $SOLO h...
# 4       $nio Top analyst price target for next week. \...
# ...

# %% [markdown]
# # BYD's Twitter

# %%
import snscrape.modules.twitter as sntwitter
import pandas as pd

query = "(@$BYDDY) lang:en until:2022-08-27 since:2020-07-30"                 # Query for BYD tweets with date range in twitter
tweets = []
limits = 100000

for tweet in sntwitter.TwitterSearchScraper(query).get_items():
    
    if len(tweets) == limits:
        break
    else:
        tweets.append([tweet.date, tweet.user.username, tweet.content])    # creating columns
        
df3 = pd.DataFrame(tweets, columns=['Date','User','Tweet'])
df3.to_csv('BYDDY_tweets1.csv')                                                 # to save to csv
df3                                                                         # show what does df contains
# Out:
#                           Date             User  \
# 0    2022-08-26 17:43:18+00:00       Quantumup1
# 1    2022-08-26 09:39:30+00:00     newsfilterio
# 2    2022-08-26 09:17:19+00:00      thePandaily
# 3    2022-08-26 09:07:34+00:00  Pineapplestocks
# 4    2022-08-25 23:21:10+00:00         WKRBNews
# ...                        ...              ...
# 2327 2020-08-11 03:29:46+00:00         WKRBNews
# 2328 2020-08-10 21:35:41+00:00        midetimes
# 2329 2020-08-10 21:35:40+00:00  dailypoliticaln
# 2330 2020-08-05 00:23:05+00:00      mnguyen_saa
# 2331 2020-07-30 15:43:00+00:00        SpacBobby
#
#                                                   Tweet
# 0     BofA~China/U.S. reached preliminary agreement ...
# 1     FREYR Battery: Cautious Following Wall St. Upg...
# 2     On August 26, @BYDCompany 's new medium-sized ...
# 3     Is Tesla&amp;#8217;s Hypergrowth Story Over Or...
# 4     BYD Company Limited $BYDDY Short Interest Upda...
# ...
