# %% [markdown]
# # Data Cleaning

# %% [markdown]
# # Li Auto

# %%
import pandas as pd
import re
import numpy


LI_Tweets_Clean = pd.read_csv('LI_tweets.csv')
LI_Tweets_Clean = LI_Tweets_Clean.drop_duplicates()
LI_Tweets_Clean['Date2'] = LI_Tweets_Clean['Date'].str[:10]
LI_Tweets_Clean['Time'] = LI_Tweets_Clean['Date'].str[10:19]
LI_Tweets_Clean=LI_Tweets_Clean.drop(LI_Tweets_Clean.columns[0], axis=1)

def cleanTxt(text):
    
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)
    text = re.sub(r"#", "", text)                        #Remove '#' symbol
    text = re.sub(r"RT[\s]", "", text)                   #Remove RT  
    text = re.sub(r"-", "", text)                        #Remove '-'
    text = re.sub(r":", "", text)                        #Remove ':'
    text = re.sub(r";", "", text)                        #Remove ';'
    text = re.sub(r",", "", text)                        #Remove ','
    text = re.sub(r"(\n)", "", text)                     #Remove new line in string
    text = re.sub(r"(\W)", " ", text)                    #Remove non-alphanumeric characters
    text = re.sub(' +', ' ', text)    
    return text

#Cleaning the text
LI_Tweets_Clean['Clean_Tweet'] = LI_Tweets_Clean['Tweet'].apply(cleanTxt)

for i in range(len(LI_Tweets_Clean['Clean_Tweet'])):
    LI_Tweets_Clean['Clean_Tweet'][i] = LI_Tweets_Clean['Clean_Tweet'][i].strip()

#Export to csv
LI_Tweets_Clean.to_csv('LI_tweets_Cleaned.csv')

#Show cleaned Text
LI_Tweets_Clean
# Out:
#                             Date             User  \
# 0      2022-08-26 23:17:25+00:00        mdsoll315
# 1      2022-08-26 22:36:03+00:00        mdsoll315
# 2      2022-08-26 22:13:43+00:00   SuccessAfter25
# 3      2022-08-26 21:57:42+00:00  Charlot68911596
# 4      2022-08-26 21:34:41+00:00        mdsoll315
# ...                          ...              ...
# 48467  2020-07-30 05:46:43+00:00        PFQdokkan
# 48468  2020-07-30 05:08:42+00:00  stonksfrmytesla
# 48469  2020-07-30 04:34:31+00:00  Plantagenet1455
# 48470  2020-07-30 04:19:53+00:00       Junheng_Li
# 48471  2020-07-30 01:22:57+00:00     BellhouseJay
#
#                                                    Tweet       Date2  \
# 0      $PCAR is the ONLY EV up YTD.. $Li was, but was...  2022-08-26
# 1      I’m expecting a squeeze in all of China… espec...  2022-08-26
# 2      💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰💰Congrats to all Team members ...  2022-08-26
# 3      $li  is set and ready for a run up!.!.~\nhttps...  2022-08-26
# ...

# %% [markdown]
# # NIO Data Cleaning

# %%
import pandas as pd
import re
import numpy

NIO_Tweets_Clean = pd.read_csv('NIO_tweets1.csv')
NIO_Tweets_Clean = NIO_Tweets_Clean.drop_duplicates()
NIO_Tweets_Clean['Date2'] = NIO_Tweets_Clean['Date'].str[:10]
NIO_Tweets_Clean['Time'] = NIO_Tweets_Clean['Date'].str[10:19]
NIO_Tweets_Clean=NIO_Tweets_Clean.drop(NIO_Tweets_Clean.columns[0], axis=1)

def cleanTxt(text):
    
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)  #Remove hyperlinks
    text = re.sub(r"#", "", text)                                   #Remove '#' symbol
    text = re.sub(r"RT[\s]", "", text)                              #Remove RT  
    text = re.sub(r"-", "", text)                                   #Remove '-'
    text = re.sub(r":", "", text)                                   #Remove ':'
    text = re.sub(r";", "", text)                                   #Remove ';'
    text = re.sub(r",", "", text)                                   #Remove ','
    text = re.sub(r"(\n)", "", text)                                #Remove new line in string
    text = re.sub(r"(\W)", " ", text)                               #Remove non-alphanumeric characters
    text = re.sub(' +', ' ', text)    
    return text

#Cleaning the text
NIO_Tweets_Clean['Clean_Tweet'] = NIO_Tweets_Clean['Tweet'].apply(cleanTxt)

for i in range(len(NIO_Tweets_Clean['Clean_Tweet'])):
    NIO_Tweets_Clean['Clean_Tweet'][i] = NIO_Tweets_Clean['Clean_Tweet'][i].strip()

#Export to csv
NIO_Tweets_Clean.to_csv('NIO_tweets_Cleaned.csv')

#Show cleaned Text
NIO_Tweets_Clean
# Out:
#                              Date             User  \
# 0       2022-08-26 23:52:19+00:00         MrRabit8
# 1       2022-08-26 23:41:13+00:00    GBear03828377
# 2       2022-08-26 23:34:28+00:00         nxvember
# 3       2022-08-26 23:30:13+00:00         mephiljb
# 4       2022-08-26 23:28:47+00:00  RossCra41038894
# ...                           ...              ...
# 458662  2020-07-30 00:26:50+00:00     Jeff24458526
# 458663  2020-07-30 00:25:38+00:00      davidmoadel
# 458664  2020-07-30 00:22:16+00:00      TalkWithEli
# 458665  2020-07-30 00:14:50+00:00     bigmike48732
# 458666  2020-07-30 00:03:56+00:00         stoxline
#
#                                                     Tweet       Date2  \
# 0       $nio Top analyst price target for next week. \...  2022-08-26
# 1       For next week I bought puts on $F $NIO $PLTR a...  2022-08-26
# 2                        @YourBoyMilt $AMZN $NIO $SNOW 👀🥲  2022-08-26
# ...

# %% [markdown]
# # XPENG

# %%
import pandas as pd
import re
import numpy


XPENG_Tweets_Clean = pd.read_csv('XPENG_tweets.csv')
XPENG_Tweets_Clean = XPENG_Tweets_Clean.drop_duplicates()
XPENG_Tweets_Clean['Date2'] = XPENG_Tweets_Clean['Date'].str[:10]
XPENG_Tweets_Clean['Time'] = XPENG_Tweets_Clean['Date'].str[10:19]
XPENG_Tweets_Clean=XPENG_Tweets_Clean.drop(XPENG_Tweets_Clean.columns[0], axis=1)

def cleanTxt(text):
    
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)
    text = re.sub(r"#", "", text)                        #Remove '#' symbol
    text = re.sub(r"RT[\s]", "", text)                   #Remove RT  
    text = re.sub(r"-", "", text)                        #Remove '-'
    text = re.sub(r":", "", text)                        #Remove ':'
    text = re.sub(r";", "", text)                        #Remove ';'
    text = re.sub(r",", "", text)                        #Remove ','
    text = re.sub(r"(\n)", "", text)                     #Remove new line in string
    text = re.sub(r"(\W)", " ", text)                    #Remove non-alphanumeric characters
    text = re.sub(' +', ' ', text)    
    return text

#Cleaning the text
XPENG_Tweets_Clean['Clean_Tweet'] = XPENG_Tweets_Clean['Tweet'].apply(cleanTxt)

for i in range(len(XPENG_Tweets_Clean['Clean_Tweet'])):
    XPENG_Tweets_Clean['Clean_Tweet'][i] = XPENG_Tweets_Clean['Clean_Tweet'][i].strip()

#Export to csv
XPENG_Tweets_Clean.to_csv('XPENG_tweets_Cleaned.csv')

#Show cleaned Text
XPENG_Tweets_Clean
# Out:
#                             Date             User  \
# 0      2022-08-26 23:17:25+00:00        mdsoll315
# 1      2022-08-26 23:05:03+00:00       AlertTrade
# 2      2022-08-26 22:36:03+00:00        mdsoll315
# 3      2022-08-26 22:30:03+00:00  TradeWithAlerts
# 4      2022-08-26 22:17:03+00:00    Jonny09775596
# ...                          ...              ...
# 69788  2020-08-07 19:52:10+00:00          sokane1
# 69789  2020-08-07 19:45:55+00:00          sokane1
# 69790  2020-08-07 19:35:22+00:00          sokane1
# 69791  2020-08-07 18:53:49+00:00     HedgeyeChina
# 69792  2020-08-07 18:50:02+00:00        JCOviedo6
#
#                                                    Tweet       Date2  \
# 0      $PCAR is the ONLY EV up YTD.. $Li was, but was...  2022-08-26
# 1      💳  Order your FTX Crypto Card \nNo Fees!  Yes,...  2022-08-26
# 2      I’m expecting a squeeze in all of China… espec...  2022-08-26
# 3      Nice print for $XPEV Size: 247402 Price: 18.92...  2022-08-26
# ...

# %% [markdown]
# # BYD

# %%
import pandas as pd
import re
import numpy


BYDDY_Tweets_Clean = pd.read_csv('BYDDY_tweets.csv')
BYDDY_Tweets_Clean = BYDDY_Tweets_Clean.drop_duplicates()
BYDDY_Tweets_Clean['Date2'] = BYDDY_Tweets_Clean['Date'].str[:10]
BYDDY_Tweets_Clean['Time'] = BYDDY_Tweets_Clean['Date'].str[10:19]
BYDDY_Tweets_Clean=BYDDY_Tweets_Clean.drop(BYDDY_Tweets_Clean.columns[0], axis=1)

def cleanTxt(text):
    
    text = re.sub(r"(?:\@|http?\://|https?\://|www)\S+", "", text)
    text = re.sub(r"#", "", text)                        #Remove '#' symbol
    text = re.sub(r"RT[\s]", "", text)                   #Remove RT  
    text = re.sub(r"-", "", text)                        #Remove '-'
    text = re.sub(r":", "", text)                        #Remove ':'
    text = re.sub(r";", "", text)                        #Remove ';'
    text = re.sub(r",", "", text)                        #Remove ','
    text = re.sub(r"(\n)", "", text)                     #Remove new line in string
    text = re.sub(r"(\W)", " ", text)                    #Remove non-alphanumeric characters
    text = re.sub(' +', ' ', text)    
    return text

#Cleaning the text
BYDDY_Tweets_Clean['Clean_Tweet'] = BYDDY_Tweets_Clean['Tweet'].apply(cleanTxt)

for i in range(len(BYDDY_Tweets_Clean['Clean_Tweet'])):
    BYDDY_Tweets_Clean['Clean_Tweet'][i] = BYDDY_Tweets_Clean['Clean_Tweet'][i].strip()


#Export to csv
BYDDY_Tweets_Clean.to_csv('BYDDY_tweets_Cleaned.csv')

#Show cleaned Text
BYDDY_Tweets_Clean
# Out:
#                            Date             User  \
# 0     2022-08-26 17:43:18+00:00       Quantumup1
# 1     2022-08-26 09:39:30+00:00     newsfilterio
# 2     2022-08-26 09:17:19+00:00      thePandaily
# 3     2022-08-26 09:07:34+00:00  Pineapplestocks
# 4     2022-08-25 23:21:10+00:00         WKRBNews
# ...                         ...              ...
# 2283  2020-08-11 03:29:46+00:00         WKRBNews
# 2284  2020-08-10 21:35:41+00:00        midetimes
# 2285  2020-08-10 21:35:40+00:00  dailypoliticaln
# 2286  2020-08-05 00:23:05+00:00      mnguyen_saa
# 2287  2020-07-30 15:43:00+00:00        SpacBobby
#
#                                                   Tweet       Date2  \
# 0     BofA~China/U.S. reached preliminary agreement ...  2022-08-26
# 1     FREYR Battery: Cautious Following Wall St. Upg...  2022-08-26
# 2     On August 26, @BYDCompany 's new medium-sized ...  2022-08-26
# 3     Is Tesla&amp;#8217;s Hypergrowth Story Over Or...  2022-08-26
# ...
